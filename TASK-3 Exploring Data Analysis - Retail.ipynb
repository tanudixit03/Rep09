# %% [markdown]
# <font size="6"><u><b>Data Science and Business Analytics Intern </b></font>

# %% [markdown]
# <font size="3"><b><u>Author: Tanu Dixit</B></font>

# %% [markdown]
# <font size="5"><b>TASK-3: <u>Exploring Data Analysis - Retail</b></font>

# %% [markdown]
# <font size=4><b>Objective:<b/>
# * Perform Exploratory Data aNALYSIS(EDA) on dataset `SampleSuperstore` and try to find out the weak areas where you can work to make more profit.
# * What all business problems you can derieve by exploring the data?

# %% [markdown]
# <font size=3><b>Importing all requird libraries <b/>

# %%
# Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %% [markdown]
# <font size=4><b>Importing the Dataset</b>

# %%
df = pd.read_csv("SampleSuperstore.csv")
print("Superstore dataset is now loaded!")
# Out:
# Superstore dataset is now loaded!

# %% [markdown]
# <font size=6><b>Exploratory Data Analysis</B>

# %%
#Displaying the whole Dataset
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.head()#used to show first five records
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.tail()#used to show last five records from dataset
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
df.shape #to get the dimensions of the dataset
# Out:
# (9994, 13)

# %% [markdown]
# i.e 9994 rows and 13 columns are there

# %%
df.info()

# it gives a brief review of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.describe()

# to show the statistical description of the dataset
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# we can see huge difference between 75% and max value for both sales and the profits , it means there are outliers present in the data.

# %%
# now to check the presence of any null values in dataset
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# hence, no null values

# %%
#Now checking for any duplicate values
df.duplicated().sum()
# Out:
# 17

# %% [markdown]
# hence, 17 duplicated data values which need to be dropped

# %%
df.drop_duplicates(inplace=True)

# %%
#checking whether the duplicate values removed
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# hence, 0 duplicate values

# %%
df.shape
# Out:
# (9977, 13)

# %% [markdown]
# now 9977 rows left and 13 columns

# %%
#dropping the column not required
df = df.drop('Postal Code', axis=1)
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Region',
#        'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# <font size=6><b>Data Visualisation</b>

# %% [markdown]
# <B>correlation matrix using heatmap to check pairwise dependency<B/>

# %%
plt.figure(figsize=(7,4))
sns.heatmap(df.corr(), cmap = 'viridis', annot = True, linewidth = 4)


#annot = True: write the data value in each cell
# Out:
# C:\Users\Tanu\AppData\Local\Temp\ipykernel_10728\4121499344.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), cmap = 'viridis', annot = True, linewidth = 4)
# <Axes: >

# %% [markdown]
# <B>From the above heat map we can infer that:-</b>
#
#     *correlation between Sales and Profit is positive and moderate
#     *correlation between Qunatity and Discount is positive but low
#     *correlation between Profit and Discount as well as Sales and Discount are negatively correlated.

# %%
# Use of pairplot to show pairwise relationship in the Dataset
sns.pairplot(df,diag_kind='data')

# %% [markdown]
# <b>Observations:</b>
#
# *Sales increases profit also increases
#
# *As we increase the Discount profit strarts decreasing ( Discount is more than 30%, Profit decreases)
#
# *As Discount increases, Sales decreases

# %% [markdown]
# <font size=4><b>Now we will do Ship Mode wise Sales Analysis</b>

# %%
df['Ship Mode'].value_counts()
#it will return the unique values in the dataframe
# Out:
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: Ship Mode, dtype: int64

# %%
# Used a countplot for Ship Mode
plt.figure(figsize=(6,4))
sns.countplot(x=df["Ship Mode"])
plt.show()

# %% [markdown]
# Standard class most opted ship mode and Same Day is the least opted.

# %% [markdown]
# <font size=5><b> Region wise Sales Analysis</b>

# %%
df['Region'].value_counts()
# returns count of unique value from the data
# Out:
# West       3193
# East       2845
# Central    2319
# South      1620
# Name: Region, dtype: int64

# %%
#using Barplot to show profits across different regions
plt.figure(figsize = (6,4))
sns.set(font_scale=1)
sns.barplot(x='Region', y='Profit', data=df, hue='Segment')
plt.title("Profit across different Regions(by Segments)", fontsize = 15)
plt.show()

# %%
# Using pie chart to show region sales
df['Region'].value_counts().plot(kind="pie",figsize=(5,5),autopct="%1.1f%%",shadow="True")
plt.legend(fontsize=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <b>observation</b>:- Maximum no. of sales are in western region.
# Minimum no. of sales in southern region.

# %% [markdown]
# <font size=5><b> Region wise Ship Mode Analysis</b>

# %%
plt.figure(figsize=(7,6))
sns.countplot(x="Region", hue="Ship Mode", data=df,palette='magma')
plt.ylabel("Ship Mode Count")
plt.show()

# %% [markdown]
# <b>Observation</b>:-
#  Standard Class is most opted Ship Mode and Same Day is least opted Ship Mode among different regions.

# %% [markdown]
# <font size=5><b><u>Sales and Profit distribution among different Regions.</b></u>

# %%
sp = df.groupby("Region")[["Sales","Profit"]].sum().sort_values(by=["Sales","Profit"],ascending=False)
sp.plot(kind="bar", fontsize=10, color=["purple","pink"])
plt.xlabel("Region", fontsize=10)
plt.ylabel("Sales and Profit", fontsize=10)
plt.show()

# %% [markdown]
# <font size=5><b>Segment Wise Sales Analysis</b>

# %%
df['Segment'].value_counts()
#count of the values in the dataset.
# Out:
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: Segment, dtype: int64

# %%
df['Segment'].value_counts().plot(kind="pie",figsize=(5,5),autopct="%1.1f%%",fontsize = 15, colors=["green","red","royalblue"],shadow="True")
plt.legend()
plt.show()

# %% [markdown]
# <b>Observation:-
#     Consumer Sales are the highest(51.9%)

# %% [markdown]
# <font size=5><b><u>Citywise Sales Analysis</b>

# %%
df['City'].value_counts()
# Out:
# New York City      914
# Los Angeles        746
# Philadelphia       536
# San Francisco      506
# Seattle            424
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: City, Length: 531, dtype: int64

# %%
plt.figure(figsize=(20,8))
sns.countplot(x=df['City'], order=(df['City'].value_counts().head(60)).index)
plt.xticks(rotation=60)
plt.xlabel('City', fontsize = 15)
plt.ylabel('Count / No.of buyers', fontsize = 15)
plt.show()

# %% [markdown]
# <b>Observation:</b>
# New York City has highest count of buyers followed by Los Angeles and then by Philadelphia.

# %% [markdown]
# <Font size=5><b>Statewise Sales Analysis</b>

# %%
df['State'].value_counts()
# Out:
# California              1996
# New York                1127
# Texas                    983
# Pennsylvania             586
# Washington               502
# Illinois                 491
# Ohio                     468
# Florida                  383
# Michigan                 254
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   123
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
plt.figure(figsize=(20,8))
sns.countplot(x=df['State'], order=(df['State'].value_counts().head(60)).index)
plt.xticks(rotation=60)
plt.xlabel('States', fontsize = 15)
plt.ylabel('Count / No.of buyers', fontsize = 15)
plt.show()

# %% [markdown]
# <b>Observation:</b>
# California, New York, Texas has highest count of buyers and Wyoming has the least count.

# %% [markdown]
# <font size=5><b>Category wise Analysis</b>

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6012
# Furniture          2118
# Technology         1847
# Name: Category, dtype: int64

# %%
sns.barplot(x='Category', y='Sales', data=df, palette="magma")
plt.show()

# %% [markdown]
# <B>Observation:</b>
# Sales are mostly in Technology and Furniture Category.

# %%
#Barplot for profits corresponding to each category
sns.barplot(x='Category', y='Profit', data=df, palette="magma")
plt.show()

# %% [markdown]
# <b>Observation</b>:There is more profit in Technology Category and moderate in Furniture and Office Supplies category.

# %%
csp = df.groupby("Category")[["Sales","Profit"]].sum().sort_values(by=["Sales","Profit"], ascending = True)
csp.plot(kind="bar",fontsize=10, color = ["green", "red"])
plt.xlabel("Category", fontsize=10)
plt.ylabel("Sales and Profit", fontsize=10)

plt.show()

# %% [markdown]
# <b>Observation:-
#
# Sales of Office Supplies category is high as well as Profit is more.
#
# Sales of Furniture category is high but there is a little Profit.

# %% [markdown]
# <font size=5><b>Sales and profit distribution among sub-categories</B></font>

# %%
sls = df.groupby("Sub-Category")[["Sales","Profit"]].sum().sort_values(by=["Profit"], ascending = False)
sls.plot(kind="bar", figsize=(8,5), fontsize=10, color = ["orange", "purple"])
plt.xticks(rotation=70)
plt.xlabel("Sub-Category", fontsize=10)
plt.ylabel("Sales and Profit", fontsize=10)
plt.show()

# %% [markdown]
# <b>Observation</b>:
# Papers shows highest profit with moderate sales and
# Tables shows least profit with higher sales.

# %% [markdown]
# <font size=5><b>Conclusion</b>
#
# 1. There is a need to maintain the discount amount because increasing discount is hampering profits and sales.
#
# 2. Standard Class should be put in more focus as it is bringing more sales and profits.
#
# 3. There is a need to focus on the cities where maximum orders are been raised.
#
# 4. We have to concentrate on these Sub-category businesses more.
#
# 5. Sales in Office Supplies category can be increased or focused more as we can earn more Profit on that.
#
# 6. Maximum no. of sales are in western region. Minimum no. of sales in southern region.Therefore Sales can be increased in these so that to earn more profit.
#
# 7. Consumer Sales are the highest(51.9%),therefore consumers should be more encouraged to buy along with other sectors too.
